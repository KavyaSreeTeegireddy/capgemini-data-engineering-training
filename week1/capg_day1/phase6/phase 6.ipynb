# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

spark = SparkSession.builder.getOrCreate()

# %%
customers_data = [
    (1, "John Doe", "john@example.com", "Hyderabad"),
    (2, "Alice ", "alice@example.com", "Chennai"),
    (3, None, "bob@example.com", "Bangalore"),        # NULL name
    (4, "David", None, "Mumbai"),                    # NULL email
    (5, "Eva", "eva@example.com", "Hyderabad"),
    (6, "Frank", "frank@example.com", "Delhi"),
]

customers = spark.createDataFrame(customers_data, ["customer_id", "name", "email", "city"])

# %%
orders_data = [
    (101, 1, "2024-01-01", 1000),
    (102, 2, "2024-01-02", 2000),
    (103, 3, "2024-01-03", -500),     # INVALID negative value
    (104, 99, "2024-01-04", 1500),    # INVALID FK (customer_id 99)
    (105, 1, "2024-01-05", None),     # NULL amount
    (106, 5, "2024-01-06", 3000),
    (107, 5, "2024-01-07", 3000),     # duplicate-like record
]

orders = spark.createDataFrame(orders_data, ["order_id", "customer_id", "order_date", "amount"])

# %%
orders = orders.withColumn("order_date", to_date(col("order_date")))

# %%
customers = customers.filter(col("name").isNotNull() & col("email").isNotNull()).withColumn("name", trim(col("name")))
orders = orders .filter(col("amount").isNotNull()).filter(col("amount") > 0)
customers.show()
orders.show()
# Out:
# +-----------+--------+-----------------+---------+
# |customer_id|    name|            email|     city|
# +-----------+--------+-----------------+---------+
# |          1|John Doe| john@example.com|Hyderabad|
# |          2|   Alice|alice@example.com|  Chennai|
# |          5|     Eva|  eva@example.com|Hyderabad|
# |          6|   Frank|frank@example.com|    Delhi|
# +-----------+--------+-----------------+---------+
#
# +--------+-----------+----------+------+
# |order_id|customer_id|order_date|amount|
# +--------+-----------+----------+------+
# |     101|          1|2024-01-01|  1000|
# |     102|          2|2024-01-02|  2000|
# |     104|         99|2024-01-04|  1500|
# |     106|          5|2024-01-06|  3000|
# |     107|          5|2024-01-07|  3000|
# +--------+-----------+----------+------+

# %%
innerjoin_df = orders.join(customers, "customer_id", "inner")
display(innerjoin_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
leftjoin_df = orders.join(customers, "customer_id", "left")
display(leftjoin_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
invalid_fk_df = orders.join(customers, "customer_id", "left_anti")
display(invalid_fk_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>order_id</th><th>order_date</th><th>amount</th></tr></thead><tbody><tr><td>99</td><td>104</td><td>2024-01-04</td><td>1500</td></tr></tbody></table></div>

# %%
print("Orders Count:", orders.count())
print("Customers Count:", customers.count())
print("Inner Join Count:", innerjoin_df.count())
print("Left Join Count:", leftjoin_df.count())
print("Left Anti Join Count:", invalid_fk_df.count())
# Out:
# Orders Count: 5
# Customers Count: 4
# Inner Join Count: 4
# Left Join Count: 5
# Left Anti Join Count: 1

# %%
from pyspark.sql.window import Window
df = orders.join(customers, "customer_id", "inner").filter(col("amount").isNotNull() & (col("amount") > 0))
customer_city_total = df.groupBy("city", "customer_id", "name").agg(sum("amount").alias("total_amount_spend"))
city_window = Window.orderBy(col("total_amount_spend").desc())

top3_customers = customer_city_total.withColumn("rank", dense_rank().over(city_window)).filter(col("rank") <= 3)
display(top3_customers)
# Out:
# /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/expressions.py:1160: UserWarning: WARN WindowExpression: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   warnings.warn(
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
running_window = Window.orderBy("order_date").rowsBetween(Window.unboundedPreceding, 0)
running_total_df = df.withColumn("running_total", sum("amount").over(running_window))
display(running_total_df)
# Out:
# /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/expressions.py:1160: UserWarning: WARN WindowExpression: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   warnings.warn(
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
customer_total = df.groupBy("customer_id", "name").agg(sum("amount").alias("total_amount_spend"))
rank_window = Window.orderBy(col("total_amount_spend").desc())
ranked_cust = customer_total.withColumn("rank", dense_rank().over(rank_window))
display(ranked_cust)
# Out:
# /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/expressions.py:1160: UserWarning: WARN WindowExpression: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   warnings.warn(
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>name</th><th>total_amount_spend</th><th>rank</th></tr></thead><tbody><tr><td>5</td><td>Eva</td><td>6000</td><td>1</td></tr><tr><td>2</td><td>Alice</td><td>2000</td><td>2</td></tr><tr><td>1</td><td>John Doe</td><td>1000</td><td>3</td></tr></tbody></table></div>

# %%
df_with_month = df.withColumn("month", month("order_date"))
display(df_with_month)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
monthly_tot_sales = df_with_month.groupBy("month").agg(sum("amount").alias("tot_sales")).orderBy("month")
display(monthly_tot_sales)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>tot_sales</th></tr></thead><tbody><tr><td>1</td><td>9000</td></tr></tbody></table></div>

# %%
lag_window = Window.partitionBy("customer_id").orderBy("order_date")
date_difference_df = df.withColumn("prev_order_date", lag("order_date").over(lag_window)).withColumn(
    "days_diff", datediff(col("order_date"), col("prev_order_date"))
)

display(date_difference_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
trend_df = monthly_tot_sales.withColumn("prev_month_sales",
    lag("tot_sales").over(Window.orderBy("month"))).withColumn("growth",
    col("tot_sales") - col("prev_month_sales")
)

display(trend_df)
# Out:
# /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/expressions.py:1160: UserWarning: WARN WindowExpression: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   warnings.warn(
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>tot_sales</th><th>prev_month_sales</th><th>growth</th></tr></thead><tbody><tr><td>1</td><td>9000</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
df.write.mode("overwrite").csv("/Volumes/workspace/default/xx/phase6_output.csv")
