-- %%
CREATE TABLE employees (
emp_id INT PRIMARY KEY,
emp_name VARCHAR(50),
manager_id INT,
dept_id INT
);
INSERT INTO employees (emp_id, emp_name, manager_id, dept_id) VALUES
(1, 'Karthik', NULL, 1),
(2, 'Ajay', 1, 1),
(3, 'Vijay', 1, 2),
(4, 'Vinay', 2, 2),
(5, 'Meena', 3, 3),
(6, 'Veer', NULL, 4),
(7, 'Keerthi', 4, 5),
(8, 'Priya', 4, 5);
-- Out:
-- ---------------------------------------------------------------------------
-- AnalysisException                         Traceback (most recent call last)
-- File <command-5658819382142553>, line 1
-- ----> 1 get_ipython().run_cell_magic('sql', '', "CREATE TABLE employees (\nemp_id INT PRIMARY KEY,\nemp_name VARCHAR(50),\nmanager_id INT,\ndept_id INT\n);\nINSERT INTO employees (emp_id, emp_name, manager_id, dept_id) VALUES\n(1, 'Karthik', NULL, 1),\n(2, 'Ajay', 1, 1),\n(3, 'Vijay', 1, 2),\n(4, 'Vinay', 2, 2),\n(5, 'Meena', 3, 3),\n(6, 'Veer', NULL, 4),\n(7, 'Keerthi', 4, 5),\n(8, 'Priya', 4, 5);\n\n")
--
-- File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
--    2539 with self.builtin_trap:
--    2540     args = (magic_arg_s, cell)
-- -> 2541     result = fn(*args, **kwargs)
--    2543 # The code below prevents the output from being displayed
-- ...

-- %%
CREATE TABLE departments (
dept_id INT PRIMARY KEY,
dept_name VARCHAR(50)
);

INSERT INTO departments (dept_id, dept_name) VALUES
(1, 'HR'),
(2, 'IT'),
(3, 'Finance'),
(4, 'Marketing'),
(5, 'Sales');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

-- %%
CREATE TABLE projects (
project_id INT PRIMARY KEY,
project_name VARCHAR(50),
emp_id INT
);

INSERT INTO projects (project_id, project_name, emp_id) VALUES
(1, 'Project A', 1),
(2, 'Project B', 2),
(3, 'Project C', 3),
(4, 'Project D', 4),
(5, 'Project E', 5);
-- Out:
-- ---------------------------------------------------------------------------
-- AnalysisException                         Traceback (most recent call last)
-- File <command-5658819382142556>, line 1
-- ----> 1 get_ipython().run_cell_magic('sql', '', "CREATE TABLE projects (\nproject_id INT PRIMARY KEY,\nproject_name VARCHAR(50),\nemp_id INT\n);\n\nINSERT INTO projects (project_id, project_name, emp_id) VALUES\n(1, 'Project A', 1),\n(2, 'Project B', 2),\n(3, 'Project C', 3),\n(4, 'Project D', 4),\n(5, 'Project E', 5);\n")
--
-- File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
--    2539 with self.builtin_trap:
--    2540     args = (magic_arg_s, cell)
-- -> 2541     result = fn(*args, **kwargs)
--    2543 # The code below prevents the output from being displayed
--    2544 # when using magics with decorator @output_can_be_silenced
-- ...

-- %%
select e.emp_name as employee_name,m.emp_name as manager_name from employees e left join employees m on e.manager_id=m.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employee_name</th><th>manager_name</th></tr></thead><tbody><tr><td>Karthik</td><td>null</td></tr><tr><td>Ajay</td><td>Karthik</td></tr><tr><td>Vijay</td><td>Karthik</td></tr><tr><td>Vinay</td><td>Ajay</td></tr><tr><td>Meena</td><td>Vijay</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>Vinay</td></tr><tr><td>Priya</td><td>Vinay</td></tr></tbody></table></div>

-- %%
select e.emp_name,d.dept_name from employees e left join departments d on e.emp_id=d.dept_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Karthik</td><td>HR</td></tr><tr><td>Ajay</td><td>IT</td></tr><tr><td>Vijay</td><td>Finance</td></tr><tr><td>Vinay</td><td>Marketing</td></tr><tr><td>Meena</td><td>Sales</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>null</td></tr><tr><td>Priya</td><td>null</td></tr></tbody></table></div>

-- %%
select e.emp_name as employee_name,m.emp_name manager_name from employees e left join employees m on e.manager_id=m.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employee_name</th><th>manager_name</th></tr></thead><tbody><tr><td>Karthik</td><td>null</td></tr><tr><td>Ajay</td><td>Karthik</td></tr><tr><td>Vijay</td><td>Karthik</td></tr><tr><td>Vinay</td><td>Ajay</td></tr><tr><td>Meena</td><td>Vijay</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>Vinay</td></tr><tr><td>Priya</td><td>Vinay</td></tr></tbody></table></div>

-- %%
select e.emp_name from employees e left join departments d on e.dept_id=d.dept_id where d.dept_id is null
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th></tr></thead><tbody></tbody></table></div>

-- %%
select e.emp_name,p.project_id from employees e left join projects p on e.emp_id=p.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_id</th></tr></thead><tbody><tr><td>Karthik</td><td>1</td></tr><tr><td>Ajay</td><td>2</td></tr><tr><td>Vijay</td><td>3</td></tr><tr><td>Vinay</td><td>4</td></tr><tr><td>Meena</td><td>5</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>null</td></tr><tr><td>Priya</td><td>null</td></tr></tbody></table></div>

-- %%
select e.emp_name,p.project_name from employees e join projects p on e.emp_id=p.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_name</th></tr></thead><tbody><tr><td>Karthik</td><td>Project A</td></tr><tr><td>Ajay</td><td>Project B</td></tr><tr><td>Vijay</td><td>Project C</td></tr><tr><td>Vinay</td><td>Project D</td></tr><tr><td>Meena</td><td>Project E</td></tr></tbody></table></div>

-- %%
select e.emp_name,p.project_name from projects p left join employees e on p.emp_id=e.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_name</th></tr></thead><tbody><tr><td>Karthik</td><td>Project A</td></tr><tr><td>Ajay</td><td>Project B</td></tr><tr><td>Vijay</td><td>Project C</td></tr><tr><td>Vinay</td><td>Project D</td></tr><tr><td>Meena</td><td>Project E</td></tr></tbody></table></div>

-- %%
select e.emp_name,d.dept_name from employees e left join departments d on e.dept_id=d.dept_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Karthik</td><td>HR</td></tr><tr><td>Ajay</td><td>HR</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Veer</td><td>Marketing</td></tr><tr><td>Keerthi</td><td>Sales</td></tr><tr><td>Priya</td><td>Sales</td></tr></tbody></table></div>
