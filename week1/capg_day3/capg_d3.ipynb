-- %%
CREATE TABLE Emply_table (
emp_id INT,
emp_name VARCHAR(50),
department VARCHAR(50),
salary INT,
experience INT,
performance_rating CHAR(1)
);
INSERT INTO Emply_table (emp_id, emp_name, department, salary, experience, performance_rating)
VALUES
(1, 'Karthik', 'Engineering', 95000, 9, 'A'),
(2, 'Prathik', 'HR', 55000, 4, 'B'),
(3, 'Vinay', 'Finance', 78000, 10, 'B'),
(4, 'Vijay', 'Marketing', 48000, 3, 'C'),
(5, 'Anil', 'Engineering', 88000, 6, 'A'),
(6, 'Suresh', 'Finance', 92000, 12, 'A'),
(7, 'Ramesh', 'HR', 46000, 2, 'C'),
(8, 'Mahesh', 'Marketing', 67000, 7, 'B'),
(9, 'Rajesh', 'Engineering', 72000, 5, 'B'),
(10,'Naveen', 'Finance', 61000, 6, 'C'),
(11,'Deepak', 'HR', 83000, 11, 'A'),
(12,'Arjun', 'Engineering', 54000, 3, 'C'),
(13,'Kiran', 'Marketing', 76000, 8, 'A'),
(14,'Rohit', 'Finance', 68000, 4, 'B'),
(15,'Pavan', 'HR', 59000, 5, 'B'),
(16,'Srikanth', 'Engineering', 102000, 14, 'A'),
(17,'Manoj', 'Finance', 47000, 2, 'C'),
(18,'Varun', 'Marketing', 52000, 6, 'B'),
(19,'Ashok', 'HR', 74000, 9, 'A'),
(20,'Sunil', 'Engineering', 66000, 4, 'B'),
(21,'Nikhil', 'Finance', 86000, 7, 'A'),
(22,'Harish', 'Marketing', 45000, 1, 'C'),
(23,'Vamsi', 'Engineering', 79000, 8, 'B'),
(24,'Chaitanya','HR', 91000, 13, 'A'),
(25,'Lokesh', 'Finance', 58000, 5, 'B');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>25</td><td>25</td></tr></tbody></table></div>

-- %%
SELECT emp_name, salary, experience, performance_rating,
CASE
    WHEN performance_rating = 'A' THEN
        CASE
            WHEN salary > 80000 THEN
                CASE
                    WHEN experience > 5 THEN salary * 1.25
                    ELSE salary * 1.20
                END
            WHEN salary BETWEEN 50000 AND 80000 THEN salary * 1.15
        END

    WHEN performance_rating = 'B' THEN
        CASE
            WHEN experience > 5 THEN salary * 1.12
            ELSE salary * 1.10
        END

    WHEN performance_rating = 'C' THEN salary

END AS new_salary
FROM Emply_table;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>salary</th><th>experience</th><th>performance_rating</th><th>new_salary</th></tr></thead><tbody><tr><td>Karthik</td><td>95000</td><td>9</td><td>A</td><td>118750.00</td></tr><tr><td>Prathik</td><td>55000</td><td>4</td><td>B</td><td>60500.00</td></tr><tr><td>Vinay</td><td>78000</td><td>10</td><td>B</td><td>87360.00</td></tr><tr><td>Vijay</td><td>48000</td><td>3</td><td>C</td><td>48000.00</td></tr><tr><td>Anil</td><td>88000</td><td>6</td><td>A</td><td>110000.00</td></tr><tr><td>Suresh</td><td>92000</td><td>12</td><td>A</td><td>115000.00</td></tr><tr><td>Ramesh</td><td>46000</td><td>2</td><td>C</td><td>46000.00</td></tr><tr><td>Mahesh</td><td>67000</td><td>7</td><td>B</td><td>75040.00</td></tr><tr><td>Rajesh</td><td>72000</td><td>5</td><td>B</td><td>79200.00</td></tr><tr><td>Naveen</td><td>61000</td><td>6</td><td>C</td><td>61000.00</td></tr><tr><td>Deepak</td><td>83000</td><td>11</td><td>A</td><td>103750.00</td></tr><tr><td>Arjun</td><td>54000</td><td>3</td><td>C</td><td>54000.00</td></tr><tr><td>Kiran</td><td>76000</td><td>8</td><td>A</td><td>87400.00</td></tr><tr><td>Rohit</td><td>68000</td><td>4</td><td>B</td><td>74800.00</td></tr><tr><td>Pavan</td><td>59000</td><td>5</td><td>B</td><td>64900.00</td></tr><tr><td>Srikanth</td><td>102000</td><td>14</td><td>A</td><td>127500.00</td></tr><tr><td>Manoj</td><td>47000</td><td>2</td><td>C</td><td>47000.00</td></tr><tr><td>Varun</td><td>52000</td><td>6</td><td>B</td><td>58240.00</td></tr><tr><td>Ashok</td><td>74000</td><td>9</td><td>A</td><td>85100.00</td></tr><tr><td>Sunil</td><td>66000</td><td>4</td><td>B</td><td>72600.00</td></tr><tr><td>Nikhil</td><td>86000</td><td>7</td><td>A</td><td>107500.00</td></tr><tr><td>Harish</td><td>45000</td><td>1</td><td>C</td><td>45000.00</td></tr><tr><td>Vamsi</td><td>79000</td><td>8</td><td>B</td><td>88480.00</td></tr><tr><td>Chaitanya</td><td>91000</td><td>13</td><td>A</td><td>113750.00</td></tr><tr><td>Lokesh</td><td>58000</td><td>5</td><td>B</td><td>63800.00</td></tr></tbody></table></div>

-- %%
SELECT *,
CASE 
  WHEN department = 'Finance' THEN 
    CASE 
      WHEN performance_rating = 'A' THEN salary * 1.20
      WHEN performance_rating = 'B' THEN salary * 1.15
      WHEN performance_rating = 'C' THEN salary * 0.50
    END

  WHEN department = 'Engineering' THEN 
    CASE 
      WHEN performance_rating = 'A' THEN salary * 1.18
      WHEN performance_rating = 'B' THEN salary * 1.12
      WHEN performance_rating = 'C' THEN salary * 0.30
    END

  ELSE salary * 1.10
END AS updated_salary

FROM Emply_table;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>